# %% [markdown]
# # Evaluate and compare solutions here

# %%
from jkg_evaluators.challenges.data.hotels import HotelSolutionComparator

# %%
levels = [
    {"data_sizes": [10000],
     "input_sizes": [1, 2, 5, 10]},
    {"data_sizes": [10000, 50000, 100000, 200000],
     "input_sizes": [5]},
    {"data_sizes": [50000],
     "input_sizes": [1, 10, 100, 1000]},
    {"data_sizes": [500000],
     "input_sizes": [1, 10, 100, 1000]}
]

# %%
sc = HotelSolutionComparator(
    solutions_to_compare=[
        "better_solution",
        "k_nearest_v4",
        "Marci_Bence_solution",
        "Solution_AA_VA"
    ], 
    **levels[3])

# %%
sc.run_comparison()
# Out:
# solution: better_solution
# running setup-env-command for better_solution
# running etl-command for better_solution
# input size: 1 - data size: 500000
# running process-command for better_solution
# input size: 10 - data size: 500000
# running process-command for better_solution
# input size: 100 - data size: 500000
# running process-command for better_solution
# input size: 1000 - data size: 500000
# running process-command for better_solution
# running cleanup-command for better_solution
# solution: k_nearest_v4
# running setup-env-command for k_nearest_v4
# running etl-command for k_nearest_v4
# input size: 1 - data size: 500000
# running process-command for k_nearest_v4
# input size: 10 - data size: 500000
# running process-command for k_nearest_v4
# input size: 100 - data size: 500000
# running process-command for k_nearest_v4
# input size: 1000 - data size: 500000
# running process-command for k_nearest_v4
# no cleanup-command for k_nearest_v4
# solution: Marci_Bence_solution
# running setup-env-command for Marci_Bence_solution
# running etl-command for Marci_Bence_solution
# input size: 1 - data size: 500000
# running process-command for Marci_Bence_solution
# input size: 10 - data size: 500000
# running process-command for Marci_Bence_solution
# input size: 100 - data size: 500000
# running process-command for Marci_Bence_solution
# input size: 1000 - data size: 500000
# running process-command for Marci_Bence_solution
# no cleanup-command for Marci_Bence_solution
# solution: Solution_AA_VA
# running setup-env-command for Solution_AA_VA
# running etl-command for Solution_AA_VA
# input size: 1 - data size: 500000
# running process-command for Solution_AA_VA
# input size: 10 - data size: 500000
# running process-command for Solution_AA_VA
# input size: 100 - data size: 500000
# running process-command for Solution_AA_VA
# input size: 1000 - data size: 500000
# running process-command for Solution_AA_VA
# no cleanup-command for Solution_AA_VA

# %%
sc.plot_comparison()

# %%
sc.output_comparison()
# Out:
#                                              lat                 \
# solution                    Marci_Bence_solution Solution_AA_VA
# level_1 name
# 0       Les Grands Monts                     NaN     -21.369080
#         Preluna Hotel & Spa                  0.0            NaN
# 1       Mukuba Hotel                         NaN     -13.024199
#         Preluna Hotel & Spa                  0.0            NaN
# 2       Mantis St Helena                     NaN     -15.925860
# ...                                          ...            ...
# 1108    Preluna Hotel & Spa                  0.0            NaN
# 1109    Pousada Paradise                     NaN     -17.537964
#         Preluna Hotel & Spa                  0.0            NaN
# 1110    Preluna Hotel & Spa                  0.0            NaN
#         Tilal Liwa Hotel                     NaN      23.534270
#
#                                                                           lon  \
# solution                    better_solution k_nearest_v4 Marci_Bence_solution
# level_1 name
# 0       Les Grands Monts         -21.369080   -21.369080                  NaN
#         Preluna Hotel & Spa             NaN          NaN                  0.0
# 1       Mukuba Hotel             -13.024199   -13.024199                  NaN
#         Preluna Hotel & Spa             NaN          NaN                  0.0
# 2       Mantis St Helena         -15.925860   -15.925860                  NaN
# ...                                     ...          ...                  ...
# 1108    Preluna Hotel & Spa             NaN          NaN                  0.0
# 1109    Pousada Paradise         -17.537964   -17.537964                  NaN
#         Preluna Hotel & Spa             NaN          NaN                  0.0
# 1110    Preluna Hotel & Spa             NaN          NaN                  0.0
#         Tilal Liwa Hotel          23.534270    23.534270                  NaN
#
#
# solution                    Solution_AA_VA better_solution k_nearest_v4
# level_1 name
# 0       Les Grands Monts         55.671670       55.671670    55.671670
#         Preluna Hotel & Spa            NaN             NaN          NaN
# 1       Mukuba Hotel             28.660910       28.660910    28.660910
#         Preluna Hotel & Spa            NaN             NaN          NaN
# 2       Mantis St Helena         -5.717330       -5.717330    -5.717330
# ...                                    ...             ...          ...
# 1108    Preluna Hotel & Spa            NaN             NaN          NaN
# 1109    Pousada Paradise        -39.192370      -39.192370   -39.192370
#         Preluna Hotel & Spa            NaN             NaN          NaN
# 1110    Preluna Hotel & Spa            NaN             NaN          NaN
#         Tilal Liwa Hotel         53.800655       53.800655    53.800655
#
# [2247 rows x 8 columns]

# %%
sc = HotelSolutionComparator(
    solutions_to_compare=[
        "better_solution",
        "k_nearest_v4",
        "Marci_Bence_solution",
        "Solution_AA_VA"
    ], 
    **levels[1])

# %%
sc.run_comparison()
# Out:
# solution: better_solution
# running setup-env-command for better_solution
# running etl-command for better_solution
# input size: 5 - data size: 10000
# running process-command for better_solution
# running cleanup-command for better_solution
# running etl-command for better_solution
# input size: 5 - data size: 50000
# running process-command for better_solution
# running cleanup-command for better_solution
# running etl-command for better_solution
# input size: 5 - data size: 100000
# running process-command for better_solution
# running cleanup-command for better_solution
# running etl-command for better_solution
# input size: 5 - data size: 200000
# running process-command for better_solution
# running cleanup-command for better_solution
# solution: k_nearest_v4
# running setup-env-command for k_nearest_v4
# running etl-command for k_nearest_v4
# input size: 5 - data size: 10000
# running process-command for k_nearest_v4
# no cleanup-command for k_nearest_v4
# running etl-command for k_nearest_v4
# input size: 5 - data size: 50000
# running process-command for k_nearest_v4
# no cleanup-command for k_nearest_v4
# running etl-command for k_nearest_v4
# input size: 5 - data size: 100000
# running process-command for k_nearest_v4
# no cleanup-command for k_nearest_v4
# running etl-command for k_nearest_v4
# input size: 5 - data size: 200000
# running process-command for k_nearest_v4
# no cleanup-command for k_nearest_v4
# solution: Marci_Bence_solution
# running setup-env-command for Marci_Bence_solution
# running etl-command for Marci_Bence_solution
# input size: 5 - data size: 10000
# running process-command for Marci_Bence_solution
# no cleanup-command for Marci_Bence_solution
# running etl-command for Marci_Bence_solution
# input size: 5 - data size: 50000
# running process-command for Marci_Bence_solution
# no cleanup-command for Marci_Bence_solution
# running etl-command for Marci_Bence_solution
# input size: 5 - data size: 100000
# running process-command for Marci_Bence_solution
# no cleanup-command for Marci_Bence_solution
# running etl-command for Marci_Bence_solution
# input size: 5 - data size: 200000
# running process-command for Marci_Bence_solution
# no cleanup-command for Marci_Bence_solution
# solution: Solution_AA_VA
# running setup-env-command for Solution_AA_VA
# running etl-command for Solution_AA_VA
# input size: 5 - data size: 10000
# running process-command for Solution_AA_VA
# no cleanup-command for Solution_AA_VA
# running etl-command for Solution_AA_VA
# input size: 5 - data size: 50000
# running process-command for Solution_AA_VA
# no cleanup-command for Solution_AA_VA
# running etl-command for Solution_AA_VA
# input size: 5 - data size: 100000
# running process-command for Solution_AA_VA
# no cleanup-command for Solution_AA_VA
# running etl-command for Solution_AA_VA
# input size: 5 - data size: 200000
# running process-command for Solution_AA_VA
# no cleanup-command for Solution_AA_VA

# %%
sc.plot_comparison()

# %%
sc.output_comparison()
# Out:
#                                                            lat                 \
# solution                                  Marci_Bence_solution Solution_AA_VA
# level_1 name
# 0       OYO 890 Seven Suites Apartment                     NaN      21.126180
#         Sweet Guest House                             0.333264            NaN
# 1       Osda Guest House                              5.550630            NaN
#         Sea-View Zum Sperrgebiet                           NaN     -26.638694
# 2       Osda Guest House                              5.550630            NaN
#         Pousada Boa Sorte                                  NaN     -17.118592
# 3       Duchess Hotel and Spa                              NaN       9.092980
#         Osda Guest House                              5.550630            NaN
# 4       Melbourne Inn                                      NaN      13.065819
#         Osda Guest House                              5.550630            NaN
# 5       Charles Hotel                                 0.000000            NaN
#         Condomínio Salinas Park Resort                     NaN      -0.609204
# 6       Charles Hotel                                 0.000000            NaN
#         Melia Koh Samui                                    NaN       9.569350
# 7       Charles Hotel                                 0.000000            NaN
#         Hotel Solidaire Mangily                            NaN     -23.125399
# 8       Charles Hotel                                 0.000000            NaN
#         Sana Hotel International                           NaN       9.518875
# 9       Charles Hotel                                 0.000000            NaN
#         Hotel Solidaire Mangily                            NaN     -23.125399
# 10      City Hotel Duqm                                    NaN      19.617125
#         Villa Ayodele                                 5.104137            NaN
# 11      Le Meridien Fisherman's Cove                       NaN      -4.616660
#         Villa Ayodele                                 5.104137            NaN
# 12      Akwidaa Inn                                   4.758787            NaN
#         La Casa de Joy Airport Apartments                  NaN      17.128406
# 13      Akwidaa Inn                                   4.758787            NaN
#         Hotel Express Arrey                                NaN      -5.081155
# 14      Akwidaa Inn                                   4.758787            NaN
#         Casa Monte Amarelo - Casa Audilia                  NaN      14.968173
# 15      Augusta Sheoak Chalets                             NaN     -34.314470
#         Hotel Pedraza                                 0.000000            NaN
# 16      Hotel Pedraza                                 0.000000            NaN
#         Twin Lodge Galapagos Hotel                         NaN      -0.690281
# 17      Hotel Pedraza                                 0.000000            NaN
#         Punta Lagarto Aparthotel                           NaN     -27.080853
# 18      Cabañas Telayú                                     NaN      15.667217
#         Hotel Pedraza                                 0.000000            NaN
# 19      Hotel Pedraza                                 0.000000            NaN
#         Hotel Sul Real                                     NaN     -10.886907
#
#                                                                         \
# solution                                  better_solution k_nearest_v4
# level_1 name
# 0       OYO 890 Seven Suites Apartment          21.126180    21.126180
#         Sweet Guest House                             NaN          NaN
# 1       Osda Guest House                              NaN          NaN
#         Sea-View Zum Sperrgebiet               -26.638694   -26.638694
# 2       Osda Guest House                              NaN          NaN
#         Pousada Boa Sorte                      -17.118592   -17.118592
# 3       Duchess Hotel and Spa                    9.092980     9.092980
#         Osda Guest House                              NaN          NaN
# 4       Melbourne Inn                           13.065819    13.065819
#         Osda Guest House                              NaN          NaN
# 5       Charles Hotel                                 NaN          NaN
#         Condomínio Salinas Park Resort          -0.609204    -0.609204
# 6       Charles Hotel                                 NaN          NaN
#         Melia Koh Samui                          9.569350     9.569350
# 7       Charles Hotel                                 NaN          NaN
#         Hotel Solidaire Mangily                -23.125399   -23.125399
# 8       Charles Hotel                                 NaN          NaN
#         Sana Hotel International                 9.518875     9.518875
# 9       Charles Hotel                                 NaN          NaN
#         Hotel Solidaire Mangily                -23.125399   -23.125399
# 10      City Hotel Duqm                         19.617125    19.617125
#         Villa Ayodele                                 NaN          NaN
# 11      Le Meridien Fisherman's Cove            -4.616660    -4.616660
#         Villa Ayodele                                 NaN          NaN
# 12      Akwidaa Inn                                   NaN          NaN
#         La Casa de Joy Airport Apartments       17.128406    17.128406
# 13      Akwidaa Inn                                   NaN          NaN
#         Hotel Express Arrey                     -5.081155    -5.081155
# 14      Akwidaa Inn                                   NaN          NaN
#         Casa Monte Amarelo - Casa Audilia       14.968173    14.968173
# 15      Augusta Sheoak Chalets                 -34.314470   -34.314470
#         Hotel Pedraza                                 NaN          NaN
# 16      Hotel Pedraza                                 NaN          NaN
#         Twin Lodge Galapagos Hotel              -0.690281    -0.690281
# 17      Hotel Pedraza                                 NaN          NaN
#         Punta Lagarto Aparthotel               -27.080853   -27.080853
# 18      Cabañas Telayú                          15.667217    15.667217
#         Hotel Pedraza                                 NaN          NaN
# 19      Hotel Pedraza                                 NaN          NaN
#         Hotel Sul Real                         -10.886907   -10.886907
#
#                                                            lon                 \
# solution                                  Marci_Bence_solution Solution_AA_VA
# level_1 name
# 0       OYO 890 Seven Suites Apartment                     NaN      79.057820
#         Sweet Guest House                             6.728228            NaN
# 1       Osda Guest House                             -0.233910            NaN
#         Sea-View Zum Sperrgebiet                           NaN      15.152019
# 2       Osda Guest House                             -0.233910            NaN
#         Pousada Boa Sorte                                  NaN     -39.186678
# 3       Duchess Hotel and Spa                              NaN       7.498380
#         Osda Guest House                             -0.233910            NaN
# 4       Melbourne Inn                                      NaN     -59.565230
#         Osda Guest House                             -0.233910            NaN
# 5       Charles Hotel                                 0.000000            NaN
#         Condomínio Salinas Park Resort                     NaN     -47.300861
# 6       Charles Hotel                                 0.000000            NaN
#         Melia Koh Samui                                    NaN     100.083590
# 7       Charles Hotel                                 0.000000            NaN
#         Hotel Solidaire Mangily                            NaN      43.609450
# 8       Charles Hotel                                 0.000000            NaN
#         Sana Hotel International                           NaN      -7.557224
# 9       Charles Hotel                                 0.000000            NaN
#         Hotel Solidaire Mangily                            NaN      43.609450
# 10      City Hotel Duqm                                    NaN      57.640591
#         Villa Ayodele                                -1.273809            NaN
# 11      Le Meridien Fisherman's Cove                       NaN      55.421884
#         Villa Ayodele                                -1.273809            NaN
# 12      Akwidaa Inn                                  -2.025946            NaN
#         La Casa de Joy Airport Apartments                  NaN     -61.793381
# 13      Akwidaa Inn                                  -2.025946            NaN
#         Hotel Express Arrey                                NaN     -42.763711
# 14      Akwidaa Inn                                  -2.025946            NaN
#         Casa Monte Amarelo - Casa Audilia                  NaN     -24.368926
# 15      Augusta Sheoak Chalets                             NaN     115.126809
#         Hotel Pedraza                                 0.000000            NaN
# 16      Hotel Pedraza                                 0.000000            NaN
#         Twin Lodge Galapagos Hotel                         NaN     -90.310010
# 17      Hotel Pedraza                                 0.000000            NaN
#         Punta Lagarto Aparthotel                           NaN     -70.840050
# 18      Cabañas Telayú                                     NaN     -96.557178
#         Hotel Pedraza                                 0.000000            NaN
# 19      Hotel Pedraza                                 0.000000            NaN
#         Hotel Sul Real                                     NaN     -61.930591
#
#
# solution                                  better_solution k_nearest_v4
# level_1 name
# 0       OYO 890 Seven Suites Apartment          79.057820    79.057820
#         Sweet Guest House                             NaN          NaN
# 1       Osda Guest House                              NaN          NaN
#         Sea-View Zum Sperrgebiet                15.152019    15.152019
# 2       Osda Guest House                              NaN          NaN
#         Pousada Boa Sorte                      -39.186678   -39.186678
# 3       Duchess Hotel and Spa                    7.498380     7.498380
#         Osda Guest House                              NaN          NaN
# 4       Melbourne Inn                          -59.565230   -59.565230
#         Osda Guest House                              NaN          NaN
# 5       Charles Hotel                                 NaN          NaN
#         Condomínio Salinas Park Resort         -47.300861   -47.300861
# 6       Charles Hotel                                 NaN          NaN
#         Melia Koh Samui                        100.083590   100.083590
# 7       Charles Hotel                                 NaN          NaN
#         Hotel Solidaire Mangily                 43.609450    43.609450
# 8       Charles Hotel                                 NaN          NaN
#         Sana Hotel International                -7.557224    -7.557224
# 9       Charles Hotel                                 NaN          NaN
#         Hotel Solidaire Mangily                 43.609450    43.609450
# 10      City Hotel Duqm                         57.640591    57.640591
#         Villa Ayodele                                 NaN          NaN
# 11      Le Meridien Fisherman's Cove            55.421884    55.421884
#         Villa Ayodele                                 NaN          NaN
# 12      Akwidaa Inn                                   NaN          NaN
#         La Casa de Joy Airport Apartments      -61.793381   -61.793381
# 13      Akwidaa Inn                                   NaN          NaN
#         Hotel Express Arrey                    -42.763711   -42.763711
# 14      Akwidaa Inn                                   NaN          NaN
#         Casa Monte Amarelo - Casa Audilia      -24.368926   -24.368926
# 15      Augusta Sheoak Chalets                 115.126809   115.126809
#         Hotel Pedraza                                 NaN          NaN
# 16      Hotel Pedraza                                 NaN          NaN
#         Twin Lodge Galapagos Hotel             -90.310010   -90.310010
# 17      Hotel Pedraza                                 NaN          NaN
#         Punta Lagarto Aparthotel               -70.840050   -70.840050
# 18      Cabañas Telayú                         -96.557178   -96.557178
#         Hotel Pedraza                                 NaN          NaN
# 19      Hotel Pedraza                                 NaN          NaN
#         Hotel Sul Real                         -61.930591   -61.930591
