# %%
import pandas as pd
import pickle
import requests

# %%
region_df = pickle.loads(
    requests.get(
        f"https://borza-hotelcom-data.s3.eu-central-1.amazonaws.com/soccerway-region_df.pkl"
    ).content
)
competition_df = pickle.loads(
    requests.get(
        f"https://borza-hotelcom-data.s3.eu-central-1.amazonaws.com/soccerway-competition_df.pkl"
    ).content
)
season_df = pickle.loads(
    requests.get(
        f"https://borza-hotelcom-data.s3.eu-central-1.amazonaws.com/soccerway-season_df.pkl"
    ).content
)
round_df = pickle.loads(
    requests.get(
        f"https://borza-hotelcom-data.s3.eu-central-1.amazonaws.com/soccerway-round_df.pkl"
    ).content
)
match_df = pickle.loads(
    requests.get(
        f"https://borza-hotelcom-data.s3.eu-central-1.amazonaws.com/soccerway-match_df.pkl"
    ).content
)
goal_df = pickle.loads(
    requests.get(
        f"https://borza-hotelcom-data.s3.eu-central-1.amazonaws.com/soccerway-goal_df.pkl"
    ).content
)
match_info_df = pickle.loads(
    requests.get(
        f"https://borza-hotelcom-data.s3.eu-central-1.amazonaws.com/soccerway-match_info_df.pkl"
    ).content
)
lineup_df = pickle.loads(
    requests.get(
        f"https://borza-hotelcom-data.s3.eu-central-1.amazonaws.com/soccerway-lineup_df.pkl"
    ).content
)
coach_df = pickle.loads(
    requests.get(
        f"https://borza-hotelcom-data.s3.eu-central-1.amazonaws.com/soccerway-coach_df.pkl"
    ).content
)
sidelined_df = pickle.loads(
    requests.get(
        f"https://borza-hotelcom-data.s3.eu-central-1.amazonaws.com/soccerway-sidelined_df.pkl"
    ).content
)
sub_df = pickle.loads(
    requests.get(
        f"https://borza-hotelcom-data.s3.eu-central-1.amazonaws.com/soccerway-sub_df.pkl"
    ).content
)
event_df = pickle.loads(
    requests.get(
        f"https://borza-hotelcom-data.s3.eu-central-1.amazonaws.com/soccerway-event_df.pkl"
    ).content
)
player_df = pickle.loads(
    requests.get(
        f"https://borza-hotelcom-data.s3.eu-central-1.amazonaws.com/soccerway-player_df.pkl"
    ).content
)

# %%
# %run challenge_3_AA_BM.py
key_df = key_df(match_df, round_df, season_df, competition_df)
player_df_merge = name_df(player_df)

a = elso_feladat(goal_df, key_df)
print("how many players scored at least 20 goals in 4 different areas")
print(a)

b = masodik_feladat(event_df, match_info_df)
print("how many players were sent off twice by the same referee")
print(b)

c = negyedik_feladat(player_df, lineup_df)
print("how many players were sent off twice by the same referee")
print(c)

d = otodik_feladat(event_df, sub_df)
print("number of players sent off after being substituted")
print(d)

e = hatodik_feladat(event_df)
print("number of games with at least 2 missed penalties")
print(e)

top5 = top5_assister(goal_df, key_df, player_df_merge)
print("Top5 assist 5 season")
print(top5)

topsub_goal = topsub_goal(sub_df, goal_df, player_df_merge)
print("Top 5 people sub player scorer")
print(topsub_goal)

top_bench = top_bench(sub_df, player_df_merge)
print("Top 5 player sitting in bench")
print(top_bench)

top_half = top_half(goal_df, player_df_merge)
print("Top5 first half scorer")
print(top_half)

top_sideline = top_sideline(sidelined_df, player_df_merge)
print("Top5 sidelined reasons")
print(top_sideline)

feature1 = feature1(match_df)
print("the number of games they played in the last 21 days")
print(feature1)
# feature1.feature1[
# (feature1["home_team"] == 66) | (feature1["away_team"] == 66)
# ].sort_values("start_time", ascending=False)
# Out:
# how many players scored at least 20 goals in 4 different areas
# 592
# how many players were sent off twice by the same referee
# 525
# how many players were sent off twice by the same referee
# 8
# number of players sent off after being substituted
# 37273
# 3
# number of games with at least 2 missed penalties
# None
# Top5 assist 5 season
#                                   name  season_id  count
# 0                      Michael Ballack        457      4
# 3     Francisco Javier De Pedro Falque        457      3
# 5                      Christian Ziege        457      3
# 16                     Bernd Schneider        457      3
# 8             Ronaldo de Assis Moreira        457      3
# ...                                ...        ...    ...
# 1485       Matías Augusto Pérez García      18598      2
# 848        Eugenio Esteban Mena Reveco      18598      1
# 1861          Daniel da Silva Carvalho      18598      1
# 2500            Martín Nicolás Benítez      18598      1
# 3768            Fernando Gabriel Godoy      18598      1
#
# [3769 rows x 3 columns]
# Top 5 people sub player scorer
#    player_id  count                name
# 0      97253      6       Teaonui Tehau
# 1     319308      5         Ezra Walian
# 2     221603      5       Amy Rodriguez
# 3     110426      5       Sydney Leroux
# 4      41310      5  Robert Lewandowski
# Top 5 player sitting in bench
#         bench_count  player_id                   name
# 278545          363       1310           Jessy Moulin
# 228106          316      18585        Daniele Padelli
# 182042          310       4336          Marco Storari
# 76748           302      97650  Rafael Pires Monteiro
# 165694          300      17587       Germán Darío Lux
# Top5 first half scorer
#    player_id  count                                 name
# 0        382    286  Cristiano Ronaldo dos Santos Aveiro
# 1        119    278       Lionel Andrés Messi Cuccittini
# 2       3051    155    Sergio Leonel Agüero del Castillo
# 3       2290    152             Luis Alberto Suárez Díaz
# 4       5920    152         Edinson Roberto Cavani Gómez
# Top5 sidelined reasons
#         reason  player_id                     name
# 60405       15      79474           Chris Smalling
# 149678      15      97299               Phil Jones
# 276222      15      20687              Jonny Evans
# 4734        15        193        Wayne Mark Rooney
# 123628      14      55715  Rafael Pereira da Silva
# 157625      14      22357  Mario Barwuah Balotelli
# 88492       14      37785        Laurent Koscielny
# the number of games they played in the last 21 days
#         match_id  home_team  away_team          start_time  home_counter  \
# 74679    1649084         66       1388 2014-05-24 11:00:00           2.0
# 129162   2400201         66       1349 2017-10-10 10:00:00           0.0
# 104471   1434338         66       2138 2013-03-02 09:00:00           0.0
# 11       1049584         66        285 2011-03-25 09:30:00           1.0
# 129189   2400205         66        385 2018-03-27 10:30:00           0.0
# ...          ...        ...        ...                 ...           ...
# 89121    3173055      48837      48836 2019-06-14 16:00:00           0.0
# 89118    3190843      49224      49226 2019-02-15 11:00:00           1.0
# 89117    3190842      49224      49226 2019-02-13 17:00:00           0.0
# 89120    3190845      49225      49226 2019-04-18 10:00:00           1.0
# 89119    3190844      49225      49226 2019-04-16 12:00:00           0.0
#
#         away_counter
# 74679            2.0
# 129162           0.0
# 104471           0.0
# 11               1.0
# 129189           0.0
# ...              ...
# 89121            0.0
# 89118            1.0
# 89117            0.0
# 89120            1.0
# 89119            0.0
#
# [150577 rows x 6 columns]
