# %%
import pandas as pd
import yaml

# %%
results = yaml.safe_load(open("results.yaml"))

# %%
df = pd.DataFrame(results)

# %%
df.applymap(sum)\
  .pipe(lambda df: df.loc["good", :] - df.loc["bad", :])\
  .plot.barh(figsize=(14, 7))
